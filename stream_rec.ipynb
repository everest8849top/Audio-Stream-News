# %% [markdown]
# <a href="https://colab.research.google.com/github/everest8849top/Audio-Stream-News/blob/main/stream_rec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# b655161d1bb0b9933f048b7bde9666fd3a0bca8a
# http://70.34.251.235:8000/
# HIGH BITRATE stream: http://70.34.251.235:8000/test-high
# LOW BITRATE stream: http://70.34.251.235:8000/test-low

# %%
# !pip install deepgram-sdk

# %%
# !pip install aiohttp

# %%
# Example filename: deepgram_test.py

from deepgram import Deepgram
import asyncio
import aiohttp

# Your Deepgram API Key
DEEPGRAM_API_KEY = 'b655161d1bb0b9933f048b7bde9666fd3a0bca8a'

# URL for the realtime streaming audio you would like to transcribe
# URL = 'http://stream.live.vc.bbcmedia.co.uk/bbc_world_service'
URL = 'http://70.34.251.235:8000/test-high'

async def main():
  # Initialize the Deepgram SDK
  deepgram = Deepgram(DEEPGRAM_API_KEY)

  # Create a websocket connection to Deepgram
  # In this example, punctuation is turned on, interim results are turned off, and language is set to UK English.
  try:
    deepgramLive = await deepgram.transcription.live({
      'smart_format': True,
      'interim_results': False,
      'language': 'en-US',
      'model': 'nova',
    })
  except Exception as e:
    print(f'Could not open socket: {e}')
    return

  # Listen for the connection to close
  deepgramLive.registerHandler(deepgramLive.event.CLOSE, lambda c: print(f'Connection closed with code {c}.'))

  # Listen for any transcripts received from Deepgram and write them to the console
  deepgramLive.registerHandler(deepgramLive.event.TRANSCRIPT_RECEIVED, print)

  # Listen for the connection to open and send streaming audio from the URL to Deepgram
  async with aiohttp.ClientSession() as session:
    async with session.get(URL) as audio:
      while True:
        data = await audio.content.readany()
        deepgramLive.send(data)

        # If no data is being sent from the live stream, then break out of the loop.
        if not data:
            break

  # Indicate that we've finished sending data by sending the customary zero-byte message to the Deepgram streaming endpoint, and wait until we get back the final summary metadata object
  await deepgramLive.finish()

# If running in a Jupyter notebook, Jupyter is already running an event loop, so run main with this line instead:
#await main()
await main()
#asyncio.run(main())
# Out:
# {'type': 'Results', 'channel_index': [0, 1], 'duration': 3.05, 'start': 0.0, 'is_final': True, 'speech_final': False, 'channel': {'alternatives': [{'transcript': "Order. I got power bills don't draw you.", 'confidence': 0.8157199, 'words': [{'word': 'order', 'start': 0.0, 'end': 0.5, 'confidence': 0.5216935, 'punctuated_word': 'Order.'}, {'word': 'i', 'start': 0.56, 'end': 0.71999997, 'confidence': 0.8157199, 'punctuated_word': 'I'}, {'word': 'got', 'start': 0.71999997, 'end': 0.96, 'confidence': 0.88442457, 'punctuated_word': 'got'}, {'word': 'power', 'start': 0.96, 'end': 1.28, 'confidence': 0.8926654, 'punctuated_word': 'power'}, {'word': 'bills', 'start': 1.28, 'end': 1.68, 'confidence': 0.6939175, 'punctuated_word': 'bills'}, {'word': "don't", 'start': 1.68, 'end': 1.92, 'confidence': 0.78694695, 'punctuated_word': "don't"}, {'word': 'draw', 'start': 1.92, 'end': 2.08, 'confidence': 0.76172835, 'punctuated_word': 'draw'}, {'word': 'you', 'start': 2.08, 'end': 2.58, 'confidence':
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1fd609aec775> in <cell line: 1>()
# ----> 1 deepgramLive = await deepgram.transcription.live({
#       2   'punctuate': True,
#       3   'interim_results': False,
#       4   'language': 'es'
#       5 })
#
# NameError: name 'deepgram' is not defined
